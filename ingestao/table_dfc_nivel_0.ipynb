# %%
# %sql
USE CATALOG bitz;
USE SCHEMA silver;

# %%
# %sql
DROP TABLE IF EXISTS bitz.silver.dim_dfc_nivel_0;

CREATE TABLE IF NOT EXISTS bitz.silver.dim_dfc_nivel_0 (
  codigo INT,
  nome   STRING,
  indice INT
)
USING DELTA;

-- carga dos registros (ajuste os códigos se precisar)
INSERT INTO bitz.silver.dim_dfc_nivel_0 (codigo, nome, indice) VALUES
(0,   'ATIVIDADES OPERACIONAIS',                                           1),
(90,  ' = FLUXO DE CAIXA OPERACIONAL',                                      2),

(1,   'ATIVIDADES DE INVESTIMENTOS',                                       3),
(91,  ' = Caixa Líquido de Atividades de Investimento',                     4),
(92,  ' = FLUXO DE CAIXA OPERACIONAL LIVRE - FCOL',                         5),

(2,   'ATIVIDADES FINANCEIRAS',                                            6),
(93,  ' = Fluxo de Caixa da Dívida',                                        7),
(94,  'FLUXO DE CAIXA DO ACIONISTA - BRUTO',                             8),
(95,  ' = Fluxo de Caixa do Acionista',                                     9),
(96,  ' = FLUXO DE CAIXA DO ACIONISTA - LÍQUIDO',                           10),

(3,   'OUTRAS TRANSAÇÕES FINANCEIRAS',                                     11),
(97,  '   = Variação de Contas do Ativo Lgo. Prazo',                         12),
(98,  '   = Variação de Contas do Passivo Lgo.Prazo',                        13),
(99,  '   = Total de Outras Transações Financeiras',                          14),

(100, '   = VARIAÇÃO DE CAIXA',                                                 15),
(101, '(+) SALDO INICIAL (caixa + bancos + ap. financeiras)',              16),
(102, '(=) SALDO FINAL (caixa + bancos + ap. financeiras)',                17);
