# %%
# %sql
USE CATALOG bitz;
USE SCHEMA silver;

# %%
# %sql
DROP TABLE IF EXISTS bitz.silver.dim_dre_nivel_0;

CREATE TABLE IF NOT EXISTS bitz.silver.dim_dre_nivel_0 (codigo INT, nome STRING, indice INT) USING DELTA;

INSERT INTO bitz.silver.dim_dre_nivel_0 (codigo, nome, indice)
VALUES (1, '1. RECEITA OPERACIONAL BRUTA (vendas)', 1),
       (2, '2. (-) DEDUÇÕES E ABATIMENTOS (sobre vendas)', 2),
       (3, '3. (=) RECEITA LÍQUIDA', 3),
       (4, '4. (-) CUSTOS  SOBRE VENDAS', 4),
       (5, '5.  =  LUCRO BRUTO', 5),
       (6, '6. (-) DESPESAS ', 6),
       (99, '(=) EBIT', 7),
       (7, '7. OUTRAS RECEITAS E DESPESAS', 8),
       (8, '8. DESPESAS FINANCEIRAS', 9),
       (9, '9. (-) Provisão para Imposto de Renda e Contribuição Social Sobre o Lucro', 10),
       (10, '10. (=) LUCRO ANTES DAS PARTICIPAÇÕES', 11),
       (11, '11. (=) LUCRO LÍQUIDO DO EXERCÍCIO', 12);
