# %%
# %sql
USE CATALOG bitz;
USE SCHEMA silver;

# %%
# %sql
DROP TABLE IF EXISTS bitz.silver.dim_fcp_nivel_0;

CREATE TABLE IF NOT EXISTS bitz.silver.dim_fcp_nivel_0 (codigo INT, nome STRING, indice INT) USING DELTA;

INSERT INTO bitz.silver.dim_fcp_nivel_0 (codigo, nome, indice)
VALUES (0, 'ENTRADAS', 1),
       (1, 'SAIDAS', 2),
       (2, 'INVESTIMENTOS', 3),
       (99, 'VARIAÇÃO DE CAIXA', 4),
       (100, 'SALDO INICIAL', 5),
       (101, 'SALDO FINAL', 6);
