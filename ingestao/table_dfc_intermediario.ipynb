# %%
# %sql
USE CATALOG bitz;
USE SCHEMA silver;

# %%
# %sql

DROP TABLE IF EXISTS bitz.silver.dim_dfc_intermediario;

CREATE TABLE IF NOT EXISTS bitz.silver.dim_dfc_intermediario (
    cod_raiz   INT,
    cod_grupo  INT,
    nome       STRING,
    indice     INT
)
USING DELTA;

INSERT INTO bitz.silver.dim_dfc_intermediario (
    cod_raiz,
    cod_grupo,
    nome,
    indice
)
VALUES
    (0,  1,  'Entradas',    1),
    (0,  2,  'Entradas',    2),
    (0,  3,  'Pagamentos',  3),
    (0,  4,  'Pagamentos',  4),
    (0,  5,  'Pagamentos',  5),
    (0,  6,  'Pagamentos',  6),
    (0,  7,  'Pagamentos',  7),
    (0,  8,  'Pagamentos',  8),
    (0,  9,  'Pagamentos',  9),
    (0, 10,  'Pagamentos', 10),
    (0, 11,  'Pagamentos', 11),
    (0, 12,  'Pagamentos', 12);
